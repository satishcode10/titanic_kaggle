# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv("/Users/satishadhikari/Downloads/train.csv")

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test_data = pd.read_csv("/Users/satishadhikari/Downloads/test.csv")

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
gender_sub = pd.read_csv("/Users/satishadhikari/Downloads/gender_submission.csv")

# %%
gender_sub
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
print("Training data number of rows and columns : ", train_data.shape)
print("Test data number of rows and columns : ", test_data.shape)
# Out:
# Training data number of rows and columns :  (891, 12)
# Test data number of rows and columns :  (418, 11)

# %%
gender_sub.shape
# Out:
# (418, 2)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
train_data.isnull().sum().sort_values(ascending = False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# dtype: int64

# %%
test_data.isnull().sum().sort_values(ascending = False)
# Out:
# Cabin          327
# Age             86
# Fare             1
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Embarked         0
# dtype: int64

# %%
import missingno

# %%
missingno.matrix(train_data)
# Out:
# <Axes: >

# %%
missingno.matrix(test_data)
# Out:
# <Axes: >

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test_data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
#categoical variable

# %%
train_data['Sex'].value_counts(dropna = False)   #null values cha bhane ni count huncha
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
test_data['Sex'].value_counts(dropna = False)
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
train_data[['Sex','Survived']].groupby('Sex', as_index = False ).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
train_data[['Embarked','Survived']].groupby('Embarked', as_index = False ).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
train_data['Pclass'].value_counts(dropna = False)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
train_data[['Pclass', 'Survived']].groupby('Pclass', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train_data['Embarked'].value_counts(dropna = False)
# Out:
# Embarked
# S      644
# C      168
# Q       77
# NaN      2
# Name: count, dtype: int64

# %%
train_data[['Embarked', 'Survived']].groupby('Embarked', as_index = False ).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x = 'Sex', y = 'Survived', data = train_data)
plt.ylabel('Survival Rate')
plt.title('Survival Rate of male and female passenger')
# Out:
# Text(0.5, 1.0, 'Survival Rate of male and female passenger')

# %%
sns.barplot(x= 'Pclass', y = 'Survived', data = train_data)
plt.ylabel('Survival Rate')
plt.title('Survival Rate of passenger based on class')
# Out:
# Text(0.5, 1.0, 'Survival Rate of passenger based on class')

# %%
sns.catplot(x= 'Pclass', y = 'Survived', hue = 'Sex', data = train_data, kind = 'bar')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by class and sex')
# Out:
# Text(0.5, 1.0, 'Survival Rate by class and sex')

# %%
sns.catplot(x= 'Pclass', col = 'Embarked', data= train_data, kind = 'count')

# %%
train_data['Age'].fillna(train_data['Age'].median(), inplace=True)

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data['Age'].isnull().sum()
# Out:
# 0

# %%
train_data['Embarked'].fillna(train_data['Embarked'].mode()[0],inplace= True)

# %%
train_data['Embarked'].isnull().sum()
# Out:
# 0

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis = 1, inplace = True)

# %%
train_data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  28.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data['Age'].fillna(test_data['Age'].median(), inplace = True)

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test_data['Fare'].fillna(test_data['Fare'].median(), inplace = True)

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data['Fare'].isnull().sum()
# Out:
# 0

# %%
test_data.drop(['Name', 'Ticket', 'Cabin'], axis = 1, inplace = True)

# %%
test_data
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0            892       3    male  34.5      0      0    7.8292        Q
# 1            893       3  female  47.0      1      0    7.0000        S
# 2            894       2    male  62.0      0      0    9.6875        Q
# 3            895       3    male  27.0      0      0    8.6625        S
# 4            896       3  female  22.0      1      1   12.2875        S
# ..           ...     ...     ...   ...    ...    ...       ...      ...
# 413         1305       3    male  27.0      0      0    8.0500        S
# 414         1306       1  female  39.0      0      0  108.9000        C
# 415         1307       3    male  38.5      0      0    7.2500        S
# 416         1308       3    male  27.0      0      0    8.0500        S
# 417         1309       3    male  27.0      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
train_data['SibSp'].value_counts(dropna = False)
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
train_data[['SibSp', 'Survived']].groupby('SibSp', as_index = False).mean().sort_values(by='Survived', ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
sns.barplot(x = 'SibSp', y= 'Survived', data = train_data)
plt.ylabel('Survival Rate')
plt.title('Survival Rate by number of siblings')
# Out:
# Text(0.5, 1.0, 'Survival Rate by number of siblings')

# %%
train_data['Sex']= train_data['Sex'].replace({'male':0, 'female':1})

# %%
train_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    0  22.0      1      0   7.2500        S
# 1           1       1    1  38.0      1      0  71.2833        C
# 2           1       3    1  26.0      0      0   7.9250        S
# 3           1       1    1  35.0      1      0  53.1000        S
# 4           0       3    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    0  27.0      0      0  13.0000        S
# 887         1       1    1  19.0      0      0  30.0000        S
# 888         0       3    1  28.0      1      2  23.4500        S
# 889         1       1    0  26.0      0      0  30.0000        C
# 890         0       3    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
test_data['Sex']= test_data['Sex'].replace({'male':0, "female":1})

# %%
test_data
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch      Fare Embarked
# 0            892       3    0  34.5      0      0    7.8292        Q
# 1            893       3    1  47.0      1      0    7.0000        S
# 2            894       2    0  62.0      0      0    9.6875        Q
# 3            895       3    0  27.0      0      0    8.6625        S
# 4            896       3    1  22.0      1      1   12.2875        S
# ..           ...     ...  ...   ...    ...    ...       ...      ...
# 413         1305       3    0  27.0      0      0    8.0500        S
# 414         1306       1    1  39.0      0      0  108.9000        C
# 415         1307       3    0  38.5      0      0    7.2500        S
# 416         1308       3    0  27.0      0      0    8.0500        S
# 417         1309       3    0  27.0      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
#preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
train_data['Embarked'] = encoder.fit_transform(train_data['Embarked'])

# %%
train_data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    0  22.0      1      0   7.2500         2
# 1         1       1    1  38.0      1      0  71.2833         0
# 2         1       3    1  26.0      0      0   7.9250         2
# 3         1       1    1  35.0      1      0  53.1000         2
# 4         0       3    0  35.0      0      0   8.0500         2

# %%
#feature engineering

#we change the column sibsp and parch to one single column  and we add +1 at the end inorder to include the passenger as well
# eg: sibsp(2) + parch (2) + 1(passenger on the titanic) = 5 (total family size)

# %%
train_data['Family Size'] = train_data['SibSp'] + train_data['Parch'] + 1
test_data['Family Size'] = test_data['SibSp'] + test_data['Parch'] + 1

# %%
train_data.drop(['SibSp', 'Parch'], axis= 1, inplace = True)

# %%
train_data.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare  Embarked  Family Size
# 0         0       3    0  22.0   7.2500         2            2
# 1         1       1    1  38.0  71.2833         0            2
# 2         1       3    1  26.0   7.9250         2            1
# 3         1       1    1  35.0  53.1000         2            2
# 4         0       3    0  35.0   8.0500         2            1

# %%
#split data into features (X) and target(Y)

# %%
x = train_data.drop('Survived', axis = 1)
y = train_data['Survived']

# %%
x
# Out:
#      Pclass  Sex   Age     Fare  Embarked  Family Size
# 0         3    0  22.0   7.2500         2            2
# 1         1    1  38.0  71.2833         0            2
# 2         3    1  26.0   7.9250         2            1
# 3         1    1  35.0  53.1000         2            2
# 4         3    0  35.0   8.0500         2            1
# ..      ...  ...   ...      ...       ...          ...
# 886       2    0  27.0  13.0000         2            1
# 887       1    1  19.0  30.0000         2            1
# 888       3    1  28.0  23.4500         2            4
# 889       1    0  26.0  30.0000         0            1
# 890       3    0  32.0   7.7500         1            1
#
# [891 rows x 6 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
#Train-Test Split
 
data = load_iris()   #sample dataset
X = data.data
y = data.target

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_val, y_train, y_val = train_test_split(x, y, test_size= 0.2, random_state = 42)   #train_test_split is a fiunction

# %%
#Train the machine learning model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators = 100, random_state = 42)   #n_estimatirs = 100 le chai number of trees in the random forest 
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Evaluate the model
model.predict(x_val)
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(x_val)
accuracy = accuracy_score(y_val, y_pred)
print("Validation Accuracy :", accuracy)
# Out:
# Validation Accuracy : 1.0

# %%
#make predictions on the Test Set

# %%
test_data.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Family Size
# 0       3    0  34.5      0      0   7.8292         1            1
# 1       3    1  47.0      1      0   7.0000         2            2
# 2       2    0  62.0      0      0   9.6875         1            1
# 3       3    0  27.0      0      0   8.6625         2            1
# 4       3    1  22.0      1      1  12.2875         2            3

# %%
test = pd.read_csv("/Users/satishadhikari/Downloads/test.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
 test.isnull().sum().sort_values(ascending = False)
# Out:
# Cabin          327
# Age             86
# Fare             1
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Embarked         0
# dtype: int64

# %%
test['Age'].fillna(test['Age'].median(), inplace = True)

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test['Fare'].fillna(test['Fare'].median(), inplace = True)

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.drop(['Name', 'Ticket', 'Cabin'], axis= 1, inplace = True)

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0          892       3    male  34.5      0      0   7.8292        Q
# 1          893       3  female  47.0      1      0   7.0000        S
# 2          894       2    male  62.0      0      0   9.6875        Q
# 3          895       3    male  27.0      0      0   8.6625        S
# 4          896       3  female  22.0      1      1  12.2875        S

# %%
test['Family Size'] = test['SibSp'] + test['Parch']+1
test.drop(['SibSp', 'Parch'], axis=1, inplace = True)

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age     Fare Embarked  Family Size
# 0          892       3    male  34.5   7.8292        Q            1
# 1          893       3  female  47.0   7.0000        S            2
# 2          894       2    male  62.0   9.6875        Q            1
# 3          895       3    male  27.0   8.6625        S            1
# 4          896       3  female  22.0  12.2875        S            3

# %%
test['Embarked'] = encoder.fit_transform(test['Embarked'])

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age     Fare  Embarked  Family Size
# 0          892       3    male  34.5   7.8292         1            1
# 1          893       3  female  47.0   7.0000         2            2
# 2          894       2    male  62.0   9.6875         1            1
# 3          895       3    male  27.0   8.6625         2            1
# 4          896       3  female  22.0  12.2875         2            3

# %%
test['Sex'] = test['Sex'].replace({'male':0, 'female':1})

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex   Age     Fare  Embarked  Family Size
# 0          892       3    0  34.5   7.8292         1            1
# 1          893       3    1  47.0   7.0000         2            2
# 2          894       2    0  62.0   9.6875         1            1
# 3          895       3    0  27.0   8.6625         2            1
# 4          896       3    1  22.0  12.2875         2            3

# %%
type(x_test)
# Out:
# pandas.core.frame.DataFrame

# %%
print(x_test.columns)
# Out:
# Index(['Pclass', 'Sex', 'Age', 'Fare', 'Embarked', 'Family Size'], dtype='object')

# %%
x_train
# Out:
# array([[4.6, 3.6, 1. , 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [6.7, 3.1, 4.4, 1.4],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.4, 3.2, 1.3, 0.2],
#        [6.3, 2.5, 5. , 1.9],
#        [6.4, 3.2, 4.5, 1.5],
#        [5.2, 3.5, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.8, 2.7, 5.1, 1.9],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.4, 3.7, 1.5, 0.2],
#        [5.5, 2.4, 3.7, 1. ],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.6, 3. , 4.4, 1.4],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.7, 2.9, 4.2, 1.3],
#        [7.6, 3. , 6.6, 2.1],
#        [5.6, 3. , 4.5, 1.5],
#        [5.1, 3.5, 1.4, 0.2],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.8, 2.7, 4.1, 1. ],
#        [5.2, 3.4, 1.4, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [5.1, 3.8, 1.9, 0.4],
#        [5. , 2. , 3.5, 1. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [4.8, 3.4, 1.9, 0.2],
# ...

# %%
x_test
# Out:
#      Pclass  Sex   Age      Fare  Embarked  Family Size
# 0         3    0  34.5    7.8292         1            1
# 1         3    1  47.0    7.0000         2            2
# 2         2    0  62.0    9.6875         1            1
# 3         3    0  27.0    8.6625         2            1
# 4         3    1  22.0   12.2875         2            3
# ..      ...  ...   ...       ...       ...          ...
# 413       3    0  27.0    8.0500         2            1
# 414       1    1  39.0  108.9000         0            1
# 415       3    0  38.5    7.2500         2            1
# 416       3    0  27.0    8.0500         2            1
# 417       3    0  27.0   22.3583         0            3
#
# [418 rows x 6 columns]

# %%
x_test.drop(['Age', 'Fare'], axis=1)
# Out:
#      Pclass  Sex  Embarked  Family Size
# 0         3    0         1            1
# 1         3    1         2            2
# 2         2    0         1            1
# 3         3    0         2            1
# 4         3    1         2            3
# ..      ...  ...       ...          ...
# 413       3    0         2            1
# 414       1    1         0            1
# 415       3    0         2            1
# 416       3    0         2            1
# 417       3    0         0            3
#
# [418 rows x 4 columns]

# %%
x_test
# Out:
#      Pclass  Sex   Age      Fare  Embarked  Family Size
# 0         3    0  34.5    7.8292         1            1
# 1         3    1  47.0    7.0000         2            2
# 2         2    0  62.0    9.6875         1            1
# 3         3    0  27.0    8.6625         2            1
# 4         3    1  22.0   12.2875         2            3
# ..      ...  ...   ...       ...       ...          ...
# 413       3    0  27.0    8.0500         2            1
# 414       1    1  39.0  108.9000         0            1
# 415       3    0  38.5    7.2500         2            1
# 416       3    0  27.0    8.0500         2            1
# 417       3    0  27.0   22.3583         0            3
#
# [418 rows x 6 columns]
